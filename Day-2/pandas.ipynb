# %%
import pandas as pd
df = pd.read_csv("sales.csv")
print(df)
print(df.info())
print(df.isnull().sum())
df=df.drop_duplicates()
df['Profit'] = df['Profit'].fillna(df['Profit'].mean())
print(df)
# Out:
#     Order_ID  Order_Date Customer Region         Category        Product  \
# 0       1001  2026-01-05    Rahul  South      Electronics         Laptop
# 1       1002  2026-01-06    Priya  North        Furniture   Office Chair
# 2       1003  2026-01-07     Amit   West       Technology          Mouse
# 3       1004  2026-01-08    Sneha   East  Office Supplies       Notebook
# 4       1005  2026-01-09    Kiran  South      Electronics        Monitor
# 5       1006  2026-01-10   Anjali  North        Furniture          Table
# 6       1007  2026-01-11     Ravi   West       Technology       Keyboard
# 7       1008  2026-01-12    Meena   East  Office Supplies  Printer Paper
# 8       1009  2026-01-13    Arjun  South      Electronics     Smartphone
# 9       1010  2026-01-14    Divya  North        Furniture      Bookshelf
# 10      1011  2026-01-15    Vikas   West       Technology     Headphones
# 11      1012  2026-01-16    Pooja   East  Office Supplies        Pen Set
# 12      1013  2026-01-17   Nikhil  South      Electronics         Tablet
# 13      1014  2026-01-18     Neha  North        Furniture        Cabinet
# 14      1015  2026-01-19    Rohit   West       Technology         Webcam
#
#     Sales  Quantity  Profit
# 0   55000         1  8000.0
# 1    7000         2  1200.0
# 2     800         4   200.0
# 3     500        10   100.0
# 4   12000         1  2500.0
# 5   15000         1  3000.0
# 6    1500         3     NaN
# 7    1200         5   250.0
# 8   25000         1  4500.0
# 9    9000         1  1800.0
# 10   3000         2   600.0
# 11    400         8    80.0
# 12  18000         1     NaN
# 13  11000         1  2200.0
# 14   2500         2   500.0
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    15 non-null     int64
#  1   Order_Date  15 non-null     str
#  2   Customer    15 non-null     str
#  3   Region      15 non-null     str
#  4   Category    15 non-null     str
#  5   Product     15 non-null     str
#  6   Sales       15 non-null     int64
#  7   Quantity    15 non-null     int64
#  8   Profit      13 non-null     float64
# dtypes: float64(1), int64(3), str(5)
# memory usage: 1.7 KB
# None
# Order_ID      0
# Order_Date    0
# Customer      0
# Region        0
# Category      0
# Product       0
# Sales         0
# Quantity      0
# Profit        2
# dtype: int64
#     Order_ID  Order_Date Customer Region         Category        Product  \
# 0       1001  2026-01-05    Rahul  South      Electronics         Laptop
# 1       1002  2026-01-06    Priya  North        Furniture   Office Chair
# 2       1003  2026-01-07     Amit   West       Technology          Mouse
# 3       1004  2026-01-08    Sneha   East  Office Supplies       Notebook
# 4       1005  2026-01-09    Kiran  South      Electronics        Monitor
# 5       1006  2026-01-10   Anjali  North        Furniture          Table
# 6       1007  2026-01-11     Ravi   West       Technology       Keyboard
# 7       1008  2026-01-12    Meena   East  Office Supplies  Printer Paper
# 8       1009  2026-01-13    Arjun  South      Electronics     Smartphone
# 9       1010  2026-01-14    Divya  North        Furniture      Bookshelf
# 10      1011  2026-01-15    Vikas   West       Technology     Headphones
# 11      1012  2026-01-16    Pooja   East  Office Supplies        Pen Set
# 12      1013  2026-01-17   Nikhil  South      Electronics         Tablet
# 13      1014  2026-01-18     Neha  North        Furniture        Cabinet
# 14      1015  2026-01-19    Rohit   West       Technology         Webcam
#
#     Sales  Quantity       Profit
# 0   55000         1  8000.000000
# 1    7000         2  1200.000000
# 2     800         4   200.000000
# 3     500        10   100.000000
# 4   12000         1  2500.000000
# 5   15000         1  3000.000000
# 6    1500         3  1917.692308
# 7    1200         5   250.000000
# 8   25000         1  4500.000000
# 9    9000         1  1800.000000
# 10   3000         2   600.000000
# 11    400         8    80.000000
# 12  18000         1  1917.692308
# 13  11000         1  2200.000000
# 14   2500         2   500.000000

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\janak\Documents\CineMetrics_Dataset.xlsx")
df.head()
df.shape
# Out:
# (300, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_ID                   300 non-null    int64
#  1   Title                      300 non-null    object
#  2   Genre                      288 non-null    object
#  3   Release_Year               300 non-null    int64
#  4   Duration_Min               285 non-null    float64
#  5   Language                   291 non-null    object
#  6   Country                    300 non-null    object
#  7   Streaming_Platform         291 non-null    object
#  8   Budget_Million_USD         264 non-null    float64
#  9   Revenue_Million_USD        273 non-null    float64
#  10  IMDB_Rating                282 non-null    float64
#  11  Votes_Thousands            285 non-null    float64
#  12  Critic_Score               279 non-null    float64
#  13  Director_Experience_Years  288 non-null    float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 32.9+ KB

# %%
df.describe()
# Out:
#          Movie_ID  Release_Year  Duration_Min  Budget_Million_USD  \
# count  300.000000    300.000000    285.000000          264.000000
# mean   150.500000   2008.680000    112.564912           32.051515
# std     86.746758      8.854695     21.138048           34.471101
# min      1.000000   1995.000000     70.000000            2.100000
# 25%     75.750000   2001.000000     98.000000           12.800000
# 50%    150.500000   2009.000000    112.000000           22.100000
# 75%    225.250000   2016.250000    127.000000           38.450000
# max    300.000000   2024.000000    166.000000          300.000000
#
#        Revenue_Million_USD  IMDB_Rating  Votes_Thousands  Critic_Score  \
# count           273.000000   282.000000       285.000000    279.000000
# mean             83.763736     6.465957        89.589123     59.390681
# std             107.025831     1.339428        78.999020     15.403963
# min               0.000000     3.200000         5.000000     25.000000
# 25%              22.600000     5.600000        26.500000     48.000000
# 50%              51.900000     6.450000        69.600000     59.000000
# 75%             109.900000     7.400000       128.200000     70.000000
# max             906.000000     9.700000       413.800000    100.000000
#
#        Director_Experience_Years
# count                 288.000000
# mean                   19.805556
# std                    11.729695
# min                     0.000000
# 25%                    10.750000
# 50%                    20.000000
# 75%                    30.000000
# max                    40.000000

# %%
df.isnull().sum()
# Out:
# Movie_ID                      0
# Title                         0
# Genre                        12
# Release_Year                  0
# Duration_Min                 15
# Language                      9
# Country                       0
# Streaming_Platform            9
# Budget_Million_USD           36
# Revenue_Million_USD          27
# IMDB_Rating                  18
# Votes_Thousands              15
# Critic_Score                 21
# Director_Experience_Years    12
# dtype: int64

# %%
numeric_cols = ['Duration_Min', 'Budget_Million_USD', 'Revenue_Million_USD',
                'IMDB_Rating', 'Votes_Thousands', 'Critic_Score',
                'Director_Experience_Years']
for col in numeric_cols:
    df[col]= df[col].fillna(df[col].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Movie_ID                   300 non-null    int64
#  1   Title                      300 non-null    object
#  2   Genre                      288 non-null    object
#  3   Release_Year               300 non-null    int64
#  4   Duration_Min               300 non-null    float64
#  5   Language                   291 non-null    object
#  6   Country                    300 non-null    object
#  7   Streaming_Platform         291 non-null    object
#  8   Budget_Million_USD         300 non-null    float64
#  9   Revenue_Million_USD        300 non-null    float64
#  10  IMDB_Rating                300 non-null    float64
#  11  Votes_Thousands            300 non-null    float64
#  12  Critic_Score               300 non-null    float64
#  13  Director_Experience_Years  300 non-null    float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 32.9+ KB

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y = [10, 20, 30, 40, 50]
plt.plot(x,y)
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-lable")
plt.show("X-lable")
plt.show()

# %%
import matplotlib.pyplot as plt
students =["A","B","C","D"]
marks=[80,90,20,83]
plt.bar(students, marks)
plt.title("Bar Graph")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
import pandas as pd
labels =["python","java","c++","c"]
sizes=[40,30,20,10]
plt.pie(sizes,labels=labels,autopct="%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr"]
sales = [200, 300, 250, 400]

plt.bar(months, sales)
plt.title("Column Graph")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()
